# %% [markdown]
# # Project Spectral Grid generation & visualization
#
# First objective That I choose to accept the mission.
#
# Program a sliding bar that corresponds to the variable grid.teff and plots the spectrum.
#
# Author Simranjit Singh From India.

# %%
from starkit.gridkit import load_grid
grid = load_grid('C:\Users\pabla\Downloads\mygrid.h5')
grid
# Out:
# [starkit.gridkit.base][INFO   ]  Reading index (base.py:266)
# [starkit.gridkit.base][INFO   ]  Discovered columns teff, logg, mh (base.py:269)
# [starkit.gridkit.base][INFO   ]  Reading Fluxes (base.py:272)
# [starkit.gridkit.base][INFO   ]  Fluxes shape (688L, 13184L) (base.py:275)
# [py.warnings         ][WARNING]  C:\Users\pabla\Anaconda3\envs\starkit\lib\site-packages\astropy\units\format\generic.py:461: UnitsWarning: 'erg/s/angstrom' contains multiple slashes, which is discouraged by the FITS standard
#   core.UnitsWarning)
#  (generic.py:461)
# [starkit.gridkit.base][INFO   ]  Initializing spec grid (base.py:309)
# [starkit.gridkit.base][WARNING]  **** NO WAVELENGTH TYPE SET DEFAULTING TO GRID (vacuum) ****
#
#  (base.py:75)
# <SpectralGrid(teff=4000.0, logg=3.0, mh=0.0)>

# %%
import matplotlib.pyplot as plt

grid.teff = 5780.
grid.logg = 4.4
grid.mh = 0.0
wave, flux = grid()
plt.plot(wave, flux)

# %% [markdown]
# # I have add three Widgets for three Varible :-
#
# 1-Teff
#
# 2-Loff
#
# 3-Mh
#
# # Plus with the Interact Feature That has:-
#
# 1- Live output without compiling again
#
# 2- Zoom feature
#
# 3-Download

# %%
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib nbagg

x = np.linspace(0, 2, 1000)
fig, ax = plt.subplots(1, figsize=(10, 4))
plt.suptitle('Teff Logg Mh Sliding')


def update_plot(teff, logg, mh):
    
    ax.clear()
    grid.teff=teff
    grid.logg=logg
    grid.mh=mh
    wave,flux=grid()
    ax.plot(wave, flux)

    #This are the extra features that include label which is also updated as the input is changed.
    '''
    units = 'teff = {}  \nlogg = {}  \n mh = {} '
    ax.plot(wave, flux , label=units.format(teff, logg, grid))
    ax.plot(x, wave,flux, label=units.format(teff, logg, grid))
    ax.set_xlim(x[0], x[-1])
    ax.legend(loc=1)
    ax.set_xlabel('$(s)$')
    '''


teff = widgets.FloatSlider(min=1, max=10, value=1, description='Teff:')
logg = widgets.FloatSlider(min=0, max=5, value=0, description='Logg:')
mh = widgets.FloatSlider(min=1, max=10, value=1, description='Mh:')
    
widgets.interactive(update_plot, teff=grid.teff.bounds, logg=grid.logg.bounds, mh=grid.mh.bounds)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# aW50ZXJhY3RpdmUoY2hpbGRyZW49KEZsb2F0U2xpZGVyKHZhbHVlPTcwMDAuMCwgZGVzY3JpcHRpb249dSd0ZWZmJywgbWF4PTEwMDAwLjAsIG1pbj00MDAwLjApLCBGbG9hdFNsaWRlcih2YWzigKY=

# %% [markdown]
# # It was fun for me to do this as i love python. So I will be waiting for the next mission Captain and i will start finding bugs for more Pr.
#
# # My Skype Name : pablajaspreet94 for one to one Interaction.
